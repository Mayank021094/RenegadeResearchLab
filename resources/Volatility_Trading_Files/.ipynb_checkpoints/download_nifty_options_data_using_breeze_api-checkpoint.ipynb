# %%
#!pip install virtualenv
# Out:
# ...
#   Obtaining dependency information for virtualenv from https://files.pythonhosted.org/packages/4c/ed/3cfeb48175f0671ec430ede81f628f9fb2b1084c9064ca67ebe8c0ed6a05/virtualenv-20.30.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for distlib<1,>=0.3.7 from https://files.pythonhosted.org/packages/91/a1/cf2472db20f7ce4a6be1253a81cfdf85ad9c7885ffbed7047fb72c24cf87/distlib-0.3.9-py2.py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/4.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/4.3 MB 4.6 MB/s eta 0:00:01
#    ------ --------------------------------- 0.7/4.3 MB 6.9 MB/s eta 0:00:01
#    -------------- ------------------------- 1.6/4.3 MB 11.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.6/4.3 MB 13.7 MB/s eta 0:00:01
#    ------------------------------ --------- 3.3/4.3 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------------  4.3/4.3 MB 16.2 MB/s eta 0:00:01
# ...

# %%
#!pip install --upgrade breeze-connect
# Out:
# ...
#      ---------------------------------------- 0.0/55.9 kB ? eta -:--:--
#      ------- -------------------------------- 10.2/55.9 kB ? eta -:--:--
#      ------------- ------------------------ 20.5/55.9 kB 162.5 kB/s eta 0:00:01
#      ------------- ------------------------ 20.5/55.9 kB 162.5 kB/s eta 0:00:01
#      -------------------- ----------------- 30.7/55.9 kB 163.8 kB/s eta 0:00:01
#      --------------------------- ---------- 41.0/55.9 kB 195.7 kB/s eta 0:00:01
#      -------------------------------------- 55.9/55.9 kB 224.8 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for python-socketio[client] from https://files.pythonhosted.org/packages/3c/32/b4fb8585d1be0f68bde7e110dffbcf354915f77ad8c778563f0ad9655c02/python_socketio-5.13.0-py3-none-any.whl.metadata
# ...

# %% [markdown]
# ### Extracting expiry dates for years 2022, 2023 and 2024

# %%
import requests
import json
import hashlib
from datetime import datetime, timezone
from breeze_connect import BreezeConnect
import pandas as pd
from bs4 import BeautifulSoup
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
import yfinance as yf
from datetime import datetime, date, time, timezone
from dateutil.relativedelta import relativedelta

# %%
expiry_dates_json = r'<select name="expiryDate" id="expiryDate"><option value="select" selected=""> Select Expiry </option><option value="04-01-2022">04-01-2022</option><option value="06-01-2022">06-01-2022</option><option value="11-01-2022">11-01-2022</option><option value="13-01-2022">13-01-2022</option><option value="18-01-2022">18-01-2022</option><option value="20-01-2022">20-01-2022</option><option value="25-01-2022">25-01-2022</option><option value="27-01-2022">27-01-2022</option><option value="01-02-2022">01-02-2022</option><option value="03-02-2022">03-02-2022</option><option value="08-02-2022">08-02-2022</option><option value="10-02-2022">10-02-2022</option><option value="15-02-2022">15-02-2022</option><option value="17-02-2022">17-02-2022</option><option value="22-02-2022">22-02-2022</option><option value="24-02-2022">24-02-2022</option><option value="28-02-2022">28-02-2022</option><option value="03-03-2022">03-03-2022</option><option value="08-03-2022">08-03-2022</option><option value="10-03-2022">10-03-2022</option><option value="15-03-2022">15-03
option><option value="11-07-2023">11-07-2023</option><option value="12-07-2023">12-07-2023</option><option value="13-07-2023">13-07-2023</option><option value="18-07-2023">18-07-2023</option><option value="19-07-2023">19-07-2023</option><option value="20-07-2023">20-07-2023</option><option value="25-07-2023">25-07-2023</option><option value="26-07-2023">26-07-2023</option><option value="27-07-2023">27-07-2023</option><option value="01-08-2023">01-08-2023</option><option value="02-08-2023">02-08-2023</option><option value="03-08-2023">03-08-2023</option><option value="08-08-2023">08-08-2023</option><option value="09-08-2023">09-08-2023</option><option value="10-08-2023">10-08-2023</option><option value="14-08-2023">14-08-2023</option><option value="16-08-2023">16-08-2023</option><option value="17-08-2023">17-08-2023</option><option value="21-08-2023">21-08-2023</option><option value="22-08-2023">22-08-2023</option><option value="23-08-2023">23-08-2023</option><option value="24-08-2023">24-08-2023</option><option value="28-08-2023">28-08-2023</option><option value="29-08-2023">29-08-2023</option><option value="30-08-2023">30-08-2023</option><option value="31-08-2023">31-08-2023</option><option value="04-09-2023">04-09-2023</option><option value="05-09-2023">05-09-2023</option><option value="06-09-2023">06-09-2023</option><option value="07-09-2023">07-09-2023</option><option value="11-09-2023">11-09-2023</option><option value="12-09-2023">12-09-2023</option><option value="13-09-2023">13-09-2023</option><option value="14-09-2023">14-09-2023</option><option value="18-09-2023">18-09-2023</option><option value="21-09-2023">21-09-2023</option><option value="25-09-2023">25-09-2023</option><option value="26-09-2023">26-09-2023</option><option value="27-09-2023">27-09-2023</option><option value="28-09-2023">28-09-2023</option><option value="25-10-2023">25-10-2023</option><option value="26-10-2023">26-10-2023</option><option value="30-10-2023">30-10-2023</option><option value="31-10-2023">31-10-2023</option><option value="28-12-2023">28-12-2023</option></select>'
soup = BeautifulSoup(expiry_dates_json,'html.parser')
expiry_dates_2023 = convert_html_to_dates(soup)

# %%
expiry_dates_json = r'<select name="expiryDate" id="expiryDate"><option value="select" selected=""> Select Expiry </option><option value="28-03-2024">28-03-2024</option><option value="27-06-2024">27-06-2024</option><option value="26-12-2024">26-12-2024</option></select>'
soup = BeautifulSoup(expiry_dates_json,'html.parser')
expiry_dates_2024 = convert_html_to_dates(soup)

# %%
expiry_dates = expiry_dates_2023 + expiry_dates_2024

# %%
expiry_dates[60]
# Out:
# datetime.date(2023, 6, 29)

# %% [markdown]
# ### Create Breeze Session

# %%
session_key = "51233337"
secret_key = "713Z772Vm26140aN&8O0s4991u472915"
appkey = "I1988a0045&25i)2vD7`gI#95&85T9*9"

# %%
data = yf.Ticker("^NSEI")

# %%
daily_close = data.history(period='5y')[['Close']]

# %%
daily_close.index = daily_close.index.map(lambda x: x.date() if  hasattr(x, 'date') else x)

# %%
raw = daily_close[daily_close.index == expiry_dates[0]].values[0][0]
nearest_50 = round(raw / 50) * 50
nearest_50
# Out:
# 18250

# %%
for i in range(nearest_50 - 200, nearest_50 + 200 + 1, 50):
    print(i)
# Out:
# 18050
# 18100
# 18150
# 18200
# 18250
# 18300
# 18350
# 18400
# 18450

# %%
def format_expiry_date(expiry_datetime):
    # 1) If they passed a string, parse it
    if isinstance(expiry_datetime, str):
        # adjust the format string to match your input format
        expiry_datetime = datetime.strptime(expiry_datetime, "%Y-%m-%d")
        expiry_datetime = expiry_datetime.replace(tzinfo=timezone.utc)

    # 2) If they passed a date (no time), lift it to a datetime
    elif isinstance(expiry_datetime, date) and not isinstance(expiry_datetime, datetime):
        expiry_datetime = datetime.combine(
            expiry_datetime,
            time(0, 0, tzinfo=timezone.utc)
        )

    # Now expiry_datetime is guaranteed to be a datetime:
    # 3) Force it to 07:00:00 UTC
    expiry_datetime = expiry_datetime.astimezone(timezone.utc).replace(
        hour=7,
        minute=0,
        second=0,
        microsecond=0,
        tzinfo=timezone.utc
    )

    # 4) Format as ISO with milliseconds and trailing "Z"
    #    e.g.: "2022-01-11T07:00:00.000Z"
    iso = expiry_datetime.strftime("%Y-%m-%dT%H:%M:%S.%f")[:-3] + "Z"
    return iso

# %%
def download_and_save_data(
    api,
    stock,
    exch,
    strike_price,
    right,
    expiry_date,
    start_datetime,
    end_datetime,
    interval,
    export_path
):
    try:
        response = api.get_historical_data(
            interval=interval,
            from_date=start_datetime,
            to_date=end_datetime,
            stock_code=stock,
            exchange_code=exch,
            product_type="options",
            expiry_date=expiry_date,
            right=right,
            strike_price=str(strike_price)
        )
        if response and "Success" in response:
            df = pd.DataFrame(response["Success"])
            # e.g. df.to_csv(f"{export_path}/{stock}_{expiry_date}_{strike_price}_{right}.csv")
            return True, df
        else:
            return False, None
    except Exception as e:
        print(f"Error fetching data for {strike_price} {right}: {e}")
        return False, None

# %%
def fetch_data(
    api,
    stock,
    exch,
    expiry_date,
    start_datetime,
    end_datetime,
    start_strike,
    end_strike,
    step,
    max_threads=5,
    interval="1day",
    export_path="HistoricData"
):
    """
    Fetches historical options data for the given strikes and expiry,
    returns a concatenated DataFrame of all successful downloads.
    """
    # 1) Normalize expiry date
    expiry_iso = format_expiry_date(expiry_date)
    strikes = range(start_strike, end_strike + 1, step)

    def run_download_and_collect(strikes_to_run):
        collected = []
        with ThreadPoolExecutor(max_workers=max_threads) as executor:
            # submit all call/put tasks
            futures = {
                executor.submit(
                    download_and_save_data,
                    api,
                    stock,
                    exch,
                    strike,
                    right,
                    expiry_iso,
                    start_datetime,
                    end_datetime,
                    interval,
                    export_path
                ): (strike, right)
                for strike in strikes_to_run
                for right in ("call", "put")
            }
            for future, (strike, right) in futures.items():
                success, df = future.result()
                if success and isinstance(df, pd.DataFrame):
                    # annotate for traceability
                    df = df.copy()
                    df['strike'] = strike
                    df['right'] = right
                    collected.append(df)
        return collected

    # 2) First pass
    all_dfs = run_download_and_collect(strikes)

    # 3) Retry failures once
    #    we detect failures by comparing counts: expected vs obtained
    expected = {(s, r) for s in strikes for r in ("call", "put")}
    got = {(df['strike'].iloc[0], df['right'].iloc[0]) for df in all_dfs}
    failed = [s for (s, r) in expected.difference(got) for _ in (r,)]
    if failed:
        retry_dfs = run_download_and_collect(failed)
        all_dfs.extend(retry_dfs)

    # 4) Concatenate and return
    if all_dfs:
        return pd.concat(all_dfs, ignore_index=True)
    else:
        return pd.DataFrame()

# %%
breeze = BreezeConnect(api_key=appkey)
breeze.generate_session(
    api_secret=secret_key,
    session_token=session_key
)

# %%
daily_close.mean()
# Out:
# Close    18043.069592
# dtype: float64

# %%
all_dfs = []

for expiry in expiry_dates:
    
    # shift expiry one month back
    shifted = expiry - relativedelta(months=1)

    try:
        # try the exact (one‑month‑back) date first
        raw = daily_close.loc[shifted].iat[0]
    except KeyError:
        # if that’s missing, fall back to the last available row ≤ shifted
        raw = daily_close.loc[:shifted].iloc[-1, 0]
    nearest_50 = round(raw / 50) * 50
    start_strike = nearest_50 - 500
    end_strike   = nearest_50 + 500
    strikes = range(start_strike, end_strike + 1, 50)

    expiry_iso = format_expiry_date(expiry)
    rights = ["call", "put"]

    for strike in strikes:
        try:
            for right in rights:
                response = breeze.get_historical_data(
                    interval="1day",
                    from_date="2021-12-01T07:00:00.000Z",
                    to_date="2024-12-31T07:00:00.000Z",
                    stock_code="NIFTY",
                    exchange_code="NFO",
                    product_type="options",
                    right=right,
                    strike_price=str(strike),
                    expiry_date=expiry_iso
                )

                if response and "Success" in response:
                    df = pd.DataFrame(response["Success"])
                    if df.empty:
                        print(f"No data rows for strike {strike} {right} on {expiry_iso}, skipping.")
                        continue
                    print("Data fetched successfully!")
                    print(df.head())
                    df['right'] = right
                    all_dfs.append(df)
                else:
                    print(f"No data for {strike} {right} on {expiry_iso}")

        except Exception as e:
            print(f"Error fetching strike {strike} ({right}) on {expiry_iso}: {e}")

# one final concatenation
historical_options_chain = pd.concat(all_dfs, ignore_index=True)
# Out:
# No data rows for strike 18750 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18750 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18800 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18800 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18850 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18850 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18900 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18900 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18950 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 18950 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 19000 call on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 19000 put on 2023-06-29T07:00:00.000Z, skipping.
# No data rows for strike 19050 call on 2023-06-29T07:00:00.000Z, skipping.
# ...

# %%
historical_options_chain = pd.concat(all_dfs, ignore_index=True)

# %%
historical_options_chain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9264 entries, 0 to 9263
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   datetime       9264 non-null   object
#  1   stock_code     9264 non-null   object
#  2   exchange_code  9264 non-null   object
#  3   product_type   9264 non-null   object
#  4   expiry_date    9264 non-null   object
#  5   right          9264 non-null   object
#  6   strike_price   9264 non-null   object
#  7   open           9264 non-null   object
#  8   high           9264 non-null   object
#  9   low            9264 non-null   object
#  10  close          9264 non-null   object
#  11  volume         9264 non-null   object
#  12  open_interest  0 non-null      object
#  13  count          9264 non-null   int64
#  14  expiry         9264 non-null   object
#  15  strike         9264 non-null   int64
# dtypes: int64(2), object(14)
# memory usage: 1.1+ MB

# %%
historical_options_chain.to_csv("nifty_historical_options_data_broad_range.csv", index=False)

# %%
try:
    # Define parameters
    interval = "1day"  # Options: "1second", "1minute", "5minute", "30minute", "1day"
    from_date = "2021-12-01T07:00:00.000Z"  # ISO8601 format
    to_date = "2024-12-31T07:00:00.000Z"
    stock_code = "NIFTY"
    exchange_code = "NFO"
    product_type = "options"
    expiry_date = "2024-01-25T07:00:00.000Z"
    right = "call"  # Options: "call" or "put"
    strike_price = "18500"

    # Fetch historical data
    response = breeze.get_historical_data(
        interval=interval,
        from_date=from_date,
        to_date=to_date,
        stock_code=stock_code,
        exchange_code=exchange_code,
        product_type=product_type,
        right=right,
        strike_price = strike_price,
        expiry_date = expiry_date
    )

    # Process and save the data
    if response:
        data = response["Success"]
        df = pd.DataFrame(data)
        print("Data fetched successfully!")
        print(df.head())

        # Save to CSV
        df.to_csv("options_data.csv", index=False)
        print("Data saved to options_data.csv")
    else:
        print("No data returned. Check parameters or session.")
except Exception as e:
    print(f"Error fetching data: {e}")
# Out:
# Data fetched successfully!
#               datetime stock_code exchange_code product_type expiry_date  \
# 0  2023-10-30 15:02:54      NIFTY           NFO      Options   25-JAN-24
# 1  2023-10-31 15:25:25      NIFTY           NFO      Options   25-JAN-24
# 2  2023-11-01 15:15:58      NIFTY           NFO      Options   25-JAN-24
# 3  2023-11-02 15:26:53      NIFTY           NFO      Options   25-JAN-24
# 4  2023-11-03 15:29:40      NIFTY           NFO      Options   25-JAN-24
#
#   right strike_price    open    high     low    close volume open_interest  \
# 0  Call        18500  941.95    1054  941.95   996.95    650          None
# 1  Call        18500  1068.5  1068.5    1000  1049.45   1300          None
# 2  Call        18500    1000    1000     925  1007.55   2700          None
# 3  Call        18500    1038    1067   992.7   927.25   2750          None
# 4  Call        18500  1124.2  1153.9  1104.4  1057.25    850          None
#
#    count
# 0      0
# 1      1
# 2      2
# ...

# %%
response
# Out:
# {'Success': [{'datetime': '2023-10-30 15:02:54',
#    'stock_code': 'NIFTY',
#    'exchange_code': 'NFO',
#    'product_type': 'Options',
#    'expiry_date': '25-JAN-24',
#    'right': 'Call',
#    'strike_price': '18500',
#    'open': '941.95',
#    'high': '1054',
#    'low': '941.95',
#    'close': '996.95',
#    'volume': '650',
#    'open_interest': None,
#    'count': 0},
#   {'datetime': '2023-10-31 15:25:25',
#    'stock_code': 'NIFTY',
#    'exchange_code': 'NFO',
#    'product_type': 'Options',
#    'expiry_date': '25-JAN-24',
#    'right': 'Call',
#    'strike_price': '18500',
#    'open': '1068.5',
#    'high': '1068.5',
#    'low': '1000',
#    'close': '1049.45',
#    'volume': '1300',
#    'open_interest': None,
#    'count': 1},
#   {'datetime': '2023-11-01 15:15:58',
#    'stock_code': 'NIFTY',
#    'exchange_code': 'NFO',
#    'product_type': 'Options',
#    'expiry_date': '25-JAN-24',
#    'right': 'Call',
#    'strike_price': '18500',
#    'open': '1000',
# ...
